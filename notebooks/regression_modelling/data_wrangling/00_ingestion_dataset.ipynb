# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
_here = Path.cwd().resolve()
_root = next(p for p in [_here, *_here.parents] if (p / "src").is_dir())
sys.path.insert(0, str(_root / "src"))

import pandas as pd
from crime_blockgroup_mapping.constants import CITIES
from regression_modelling.data_wrangling.dataset import build_model_table
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# build dataset for houston
for city, _ in CITIES.items():
    print(f"Building city-crime table for {city}:")
    build_model_table(city)
# Out:
# Building city-crime table for houston:
# Weighted scores computed: wtotal_rel median = 1.64, wprop_rel median=1.54
# houston: model table (1629, 97) → data/processed/regression_modelling/houston_model_table.parquet
# Building city-crime table for chicago:
# Weighted scores computed: wtotal_rel median = 1.37, wprop_rel median=1.34
# chicago: model table (2164, 97) → data/processed/regression_modelling/chicago_model_table.parquet
# Building city-crime table for atlanta:
# Weighted scores computed: wtotal_rel median = 1.56, wprop_rel median=1.51
# atlanta: model table (426, 97) → data/processed/regression_modelling/atlanta_model_table.parquet
# Building city-crime table for sacramento:
# Weighted scores computed: wtotal_rel median = 0.64, wprop_rel median=0.97
# sacramento: model table (366, 97) → data/processed/regression_modelling/sacramento_model_table.parquet
# Building city-crime table for san_francisco:
# Weighted scores computed: wtotal_rel median = 1.03, wprop_rel median=1.39
# ...
