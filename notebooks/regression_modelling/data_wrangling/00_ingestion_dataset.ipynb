# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
_here = Path.cwd().resolve()
_root = next(p for p in [_here, *_here.parents] if (p / "src").is_dir())
sys.path.insert(0, str(_root / "src"))

import pandas as pd
from regression_modelling.data_wrangling.dataset import build_model_table

# %%
# build dataset for houston
hou = build_model_table("houston")
hou.info()
# Out:
# houston: model table (1629, 56) → data/processed/regression_modelling/houston_model_table.parquet
# <class 'pandas.DataFrame'>
# Index: 1629 entries, 11 to 2102
# Data columns (total 56 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   geoid                         1629 non-null   str
#  1   det_pct                       1629 non-null   float64
#  2   in_household_pct              1629 non-null   float64
#  3   moved1yr_pct                  1629 non-null   float64
#  4   Division                      1629 non-null   float64
#  5   city_centers_dist             1629 non-null   float64
#  6   pop_est_5mile                 1629 non-null   float64
#  7   pop_ch_1mile                  1629 non-null   float64
#  8   vacant_pct                    1629 non-null   float64
#  9   clip_liens_pct                1629 non-null   float64
#  10  clip_foreclosure_pct          1629 non-null   float64
#  11  unq_convenience_stores_clips  1629 non-null   float64
#  12  unq_gas_stations_clips        1629 non-null   float64
#  13  unq_liquor_stores_clips       1629 non-null   float64
#  14  transit_stop_count            1629 non-null   Int64
#  15  transit_stop_density          1629 non-null   float64
#  16  transit_nearest_stop_m        1629 non-null   float64
#  17  transit_service_intensity     1629 non-null   float64
#  18  transit_overnight_stop_count  1629 non-null   float64
#  19  transit_overnight_stop_share  1629 non-null   float64
#  20  transit_risky_stop_count      1629 non-null   float64
#  21  transit_risky_stop_share      1629 non-null   float64
#  22  transit_risky_allnight_count  1629 non-null   float64
#  23  transit_route_mode_diversity  1629 non-null   float64
#  24  within_city                   1629 non-null   bool
#  25  population                    1629 non-null   float64
#  26  cl_total_count                1629 non-null   float64
#  27  violent_count                 1629 non-null   float64
#  28  property_count                1629 non-null   float64
#  29  assault_count                 1629 non-null   float64
#  30  murder_count                  1629 non-null   float64
#  31  rape_count                    1629 non-null   float64
#  32  robbery_count                 1629 non-null   float64
#  33  burglary_count                1629 non-null   float64
#  34  larceny_count                 1629 non-null   float64
#  35  mvt_count                     1629 non-null   float64
#  36  cl_total_rate                 1628 non-null   float64
#  37  violent_rate                  1628 non-null   float64
#  38  property_rate                 1628 non-null   float64
#  39  assault_rate                  1628 non-null   float64
#  40  murder_rate                   1628 non-null   float64
#  41  rape_rate                     1628 non-null   float64
#  42  robbery_rate                  1628 non-null   float64
#  43  burglary_rate                 1628 non-null   float64
#  44  larceny_rate                  1628 non-null   float64
#  45  mvt_rate                      1628 non-null   float64
#  46  cl_total_logcount             1629 non-null   float64
#  47  violent_logcount              1629 non-null   float64
#  48  property_logcount             1629 non-null   float64
#  49  assault_logcount              1629 non-null   float64
#  50  murder_logcount               1629 non-null   float64
#  51  rape_logcount                 1629 non-null   float64
#  52  robbery_logcount              1629 non-null   float64
#  53  burglary_logcount             1629 non-null   float64
#  54  larceny_logcount              1629 non-null   float64
#  55  mvt_logcount                  1629 non-null   float64
# dtypes: Int64(1), bool(1), float64(53), str(1)
# memory usage: 735.2 KB

# %%
# build dataset for houston
chi = build_model_table("chicago")
chi.head(10)
# Out:
# chicago: model table (2164, 46) → data/processed/regression_modelling/chicago_model_table.parquet
#           geoid    det_pct  in_household_pct  moved1yr_pct  Division  \
# 0  170310101001   8.587258         96.296296     10.307609       3.0
# 1  170310101002   0.448029         96.296296     10.307609       3.0
# 2  170310101003   0.000000         96.296296     10.307609       3.0
# 3  170310102011  19.913886         98.036373     16.601165       3.0
# 4  170310102012   6.468305         98.036373     16.601165       3.0
# 5  170310102013   0.000000         98.036373     16.601165       3.0
# 6  170310102014   1.973684         98.036373     16.601165       3.0
# 7  170310102021   3.682720         88.999617     19.076923       3.0
# 8  170310102022   9.045226         88.999617     19.076923       3.0
# 9  170310103001   2.864583         84.915227     22.585794       3.0
#
#    city_centers_dist  pop_est_5mile  pop_ch_1mile  vacant_pct  clip_liens_pct  \
# 0               15.0       587573.0      4.742880    1.102941             0.0
# 1               15.0       596437.0      4.592918    4.699140             0.0
# 2               15.0       593649.0      5.047729    0.864398             0.0
# 3               15.0       679593.0      6.584727    3.839590             0.0
# 4               15.0       658823.0      5.874687    2.207506             0.0
# 5               15.0       655341.0      5.892195    3.314528             0.0
# 6               15.0       650925.0      5.700124    3.470320             0.0
# 7               15.0       630170.0      5.356201    5.125149             0.0
# 8               15.0       651659.0      4.838458    0.964630             0.0
# 9               15.0       611463.0      5.492160    2.502844             0.0
#
#    ...  cl_total_logcount  violent_logcount  property_logcount  \
# 0  ...           2.890372          1.098612           2.772589
# 1  ...           4.394449          3.135494           4.077537
# 2  ...           3.784190          2.302585           3.555348
# 3  ...           2.995732          1.945910           2.639057
# 4  ...           3.044522          1.791759           2.772589
# 5  ...           3.828641          2.302585           3.610918
# 6  ...           3.496508          2.639057           2.995732
# 7  ...           4.927254          3.688879           4.595120
# 8  ...           4.143135          2.302585           3.988984
# 9  ...           2.995732          0.000000           2.995732
#
#    assault_logcount  murder_logcount  rape_logcount  robbery_logcount  \
# 0          1.098612         0.000000       0.000000          0.000000
# 1          2.995732         0.000000       0.000000          1.386294
# 2          1.945910         0.000000       1.386294          0.000000
# 3          1.945910         0.000000       0.000000          0.000000
# 4          1.386294         0.000000       0.693147          0.693147
# 5          1.609438         0.000000       1.098612          1.386294
# 6          2.197225         0.693147       1.098612          1.098612
# 7          2.833213         0.000000       1.791759          2.944439
# 8          2.079442         0.000000       0.000000          1.098612
# 9          0.000000         0.000000       0.000000          0.000000
#
#    burglary_logcount  larceny_logcount  mvt_logcount
# 0           0.693147          2.564949      1.098612
# 1           1.386294          3.806662      2.484907
# 2           1.386294          3.135494      2.302585
# 3           0.693147          2.397895      1.098612
# 4           0.693147          2.484907      1.386294
# 5           1.945910          3.258097      1.791759
# 6           0.000000          2.484907      2.197225
# 7           1.386294          4.521789      1.609438
# 8           0.000000          3.806662      2.302585
# 9           1.098612          2.708050      1.386294
#
# [10 rows x 46 columns]
