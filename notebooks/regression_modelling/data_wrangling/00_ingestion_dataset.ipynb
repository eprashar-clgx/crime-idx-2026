# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
_here = Path.cwd().resolve()
_root = next(p for p in [_here, *_here.parents] if (p / "src").is_dir())
sys.path.insert(0, str(_root / "src"))

import pandas as pd
from regression_modelling.data_wrangling.dataset import build_model_table

# %%
# build dataset for houston
det = build_model_table("detroit")
det.info()
# Out:
# Detroit city boundary loaded: 1 row(s)
# Detroit state block groups loaded: 8,340
# Block groups within city: 622 / 8,340
# /home/eprashar_solutions_corelogic_com/crime-idx-2026/src/crime_blockgroup_mapping/boundaries.py:30: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   bg['centroid'] = bg.geometry.centroid
# Detroit year_filter [2025-01-01, 2026-01-01): kept 85,681 of 818,353 rows (0 unparseable dates dropped)
# Detroit crime data: 85,365 rows with valid coords (of 85,681)
# Matched to BG: 85,365 | Unmatched: 0
# Mapped: 45,982 / 85,365 (53.9%)
# Category counts:
# crime_category
# larceny     12604
# vandal      11036
# assault      7810
# mvt          6834
# burglary     5274
# robbery      1152
# rape          582
# fire          488
# murder        202
#
# Unmapped: 39,383 records across 23 codes
# BG-level category aggregation: 656 BGs (621 within city, 35 outside)
# ================================================================================
# Crime Totals:
# assault_count      7810.0
# murder_count        202.0
# rape_count          582.0
# robbery_count      1152.0
# burglary_count     5274.0
# larceny_count     12604.0
# mvt_count          6834.0
# vandal_count      11036.0
# violent_count      9746.0
# property_count    24712.0
# cl_total_count    34458.0
# dtype: float64
# Analysis set: 657 BGs
#   Inside city:  622 (621 with data, 1 without)
#   Outside city: 35 (all with crime data)
# Model loaded: 300,363 total BGs, 657 matched to analysis set
# Merged comparison set: 657 BGs
#   Inside city: 622 | Outside: 35
# LODES loaded: 2,288,249 blocks -> 237,793 block groups
# Normalized actuals to rate/1K: 644 BGs with population > 0
# Daytime-adjusted rates: 653 BGs with daytime_pop > 0
# detroit: model table (622, 69) → data/processed/regression_modelling/detroit_model_table.parquet
# <class 'pandas.DataFrame'>
# Index: 622 entries, 14 to 656
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   geoid                             622 non-null    str
#  1   det_pct                           622 non-null    float64
#  2   moved1yr_pct                      622 non-null    float64
#  3   own_pct                           622 non-null    float64
#  4   lap_pct                           622 non-null    float64
#  5   Division                          622 non-null    float64
#  6   city_centers_dist                 622 non-null    float64
#  7   pop_est_5mile                     622 non-null    float64
#  8   pop_ch_1mile                      622 non-null    float64
#  9   vacant_pct                        622 non-null    float64
#  10  clip_liens_pct                    622 non-null    float64
#  11  clip_foreclosure_pct              622 non-null    float64
#  12  unq_convenience_stores_clips      622 non-null    float64
#  13  unq_gas_stations_clips            622 non-null    float64
#  14  unq_liquor_stores_clips           622 non-null    float64
#  15  transit_stop_count                622 non-null    Int64
#  16  transit_stop_density              622 non-null    float64
#  17  transit_nearest_stop_m            622 non-null    float64
#  18  transit_service_intensity         622 non-null    float64
#  19  transit_overnight_stop_count      622 non-null    float64
#  20  transit_overnight_stop_share      622 non-null    float64
#  21  transit_risky_stop_count          622 non-null    float64
#  22  transit_risky_stop_share          622 non-null    float64
#  23  transit_risky_allnight_count      622 non-null    float64
#  24  transit_route_mode_diversity      622 non-null    float64
#  25  roof_condition_avg                622 non-null    float64
#  26  roof_debris_pct_avg               622 non-null    float64
#  27  roof_discoloration_pct_avg        622 non-null    float64
#  28  hardscapes_pct_avg                622 non-null    float64
#  29  roof_missing_material_pct         616 non-null    float64
#  30  imagery_structure_count           622 non-null    Int64
#  31  within_city                       622 non-null    bool
#  32  population                        622 non-null    float64
#  33  cl_total_count                    622 non-null    float64
#  34  violent_count                     622 non-null    float64
#  35  property_count                    622 non-null    float64
#  36  assault_count                     622 non-null    float64
#  37  murder_count                      622 non-null    float64
#  38  rape_count                        622 non-null    float64
#  39  robbery_count                     622 non-null    float64
#  40  burglary_count                    622 non-null    float64
#  41  larceny_count                     622 non-null    float64
#  42  mvt_count                         622 non-null    float64
#  43  cl_total_rate                     610 non-null    float64
#  44  violent_rate                      610 non-null    float64
#  45  property_rate                     610 non-null    float64
#  46  assault_rate                      610 non-null    float64
#  47  murder_rate                       610 non-null    float64
#  48  rape_rate                         610 non-null    float64
#  49  robbery_rate                      610 non-null    float64
#  50  burglary_rate                     610 non-null    float64
#  51  larceny_rate                      610 non-null    float64
#  52  mvt_rate                          610 non-null    float64
#  53  transit_has_transit               622 non-null    float64
#  54  transit_stop_count_log            622 non-null    Float64
#  55  transit_stop_density_log          622 non-null    float64
#  56  transit_nearest_stop_m_log        622 non-null    float64
#  57  transit_service_intensity_logc    622 non-null    float64
#  58  transit_overnight_stop_count_log  622 non-null    float64
#  59  cl_total_logcount                 622 non-null    float64
#  60  violent_logcount                  622 non-null    float64
#  61  property_logcount                 622 non-null    float64
#  62  assault_logcount                  622 non-null    float64
#  63  murder_logcount                   622 non-null    float64
#  64  rape_logcount                     622 non-null    float64
#  65  robbery_logcount                  622 non-null    float64
#  66  burglary_logcount                 622 non-null    float64
#  67  larceny_logcount                  622 non-null    float64
#  68  mvt_logcount                      622 non-null    float64
# dtypes: Float64(1), Int64(2), bool(1), float64(64), str(1)
# memory usage: 345.1 KB
