# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
_here = Path.cwd().resolve()
_root = next(p for p in [_here, *_here.parents] if (p / "src").is_dir())
sys.path.insert(0, str(_root / "src"))

import pandas as pd
from regression_modelling.data_wrangling.dataset import build_model_table

# %%
# build dataset for houston
hou = build_model_table("houston")
hou.info()
# Out:
# houston: model table (1629, 69) → data/processed/regression_modelling/houston_model_table.parquet
# <class 'pandas.DataFrame'>
# Index: 1629 entries, 11 to 2102
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   geoid                             1629 non-null   str
#  1   det_pct                           1629 non-null   float64
#  2   moved1yr_pct                      1629 non-null   float64
#  3   own_pct                           1629 non-null   float64
#  4   lap_pct                           1629 non-null   float64
#  5   Division                          1629 non-null   float64
#  6   city_centers_dist                 1629 non-null   float64
#  7   pop_est_5mile                     1629 non-null   float64
#  8   pop_ch_1mile                      1629 non-null   float64
#  9   vacant_pct                        1629 non-null   float64
#  10  clip_liens_pct                    1629 non-null   float64
#  11  clip_foreclosure_pct              1629 non-null   float64
#  12  unq_convenience_stores_clips      1629 non-null   float64
#  13  unq_gas_stations_clips            1629 non-null   float64
#  14  unq_liquor_stores_clips           1629 non-null   float64
#  15  transit_stop_count                1629 non-null   Int64
#  16  transit_stop_density              1629 non-null   float64
#  17  transit_nearest_stop_m            1629 non-null   float64
#  18  transit_service_intensity         1629 non-null   float64
#  19  transit_overnight_stop_count      1629 non-null   float64
#  20  transit_overnight_stop_share      1629 non-null   float64
#  21  transit_risky_stop_count          1629 non-null   float64
#  22  transit_risky_stop_share          1629 non-null   float64
#  23  transit_risky_allnight_count      1629 non-null   float64
#  24  transit_route_mode_diversity      1629 non-null   float64
#  25  roof_condition_avg                1624 non-null   float64
#  26  roof_debris_pct_avg               1624 non-null   float64
#  27  roof_discoloration_pct_avg        1624 non-null   float64
#  28  hardscapes_pct_avg                1624 non-null   float64
#  29  roof_missing_material_pct         1538 non-null   float64
#  30  imagery_structure_count           1624 non-null   Int64
#  31  within_city                       1629 non-null   bool
#  32  population                        1629 non-null   float64
#  33  cl_total_count                    1629 non-null   float64
#  34  violent_count                     1629 non-null   float64
#  35  property_count                    1629 non-null   float64
#  36  assault_count                     1629 non-null   float64
#  37  murder_count                      1629 non-null   float64
#  38  rape_count                        1629 non-null   float64
#  39  robbery_count                     1629 non-null   float64
#  40  burglary_count                    1629 non-null   float64
#  41  larceny_count                     1629 non-null   float64
#  42  mvt_count                         1629 non-null   float64
#  43  cl_total_rate                     1628 non-null   float64
#  44  violent_rate                      1628 non-null   float64
#  45  property_rate                     1628 non-null   float64
#  46  assault_rate                      1628 non-null   float64
#  47  murder_rate                       1628 non-null   float64
#  48  rape_rate                         1628 non-null   float64
#  49  robbery_rate                      1628 non-null   float64
#  50  burglary_rate                     1628 non-null   float64
#  51  larceny_rate                      1628 non-null   float64
#  52  mvt_rate                          1628 non-null   float64
#  53  transit_has_transit               1629 non-null   float64
#  54  transit_stop_count_log            1629 non-null   Float64
#  55  transit_stop_density_log          1629 non-null   float64
#  56  transit_nearest_stop_m_log        1629 non-null   float64
#  57  transit_service_intensity_logc    1629 non-null   float64
#  58  transit_overnight_stop_count_log  1629 non-null   float64
#  59  cl_total_logcount                 1629 non-null   float64
#  60  violent_logcount                  1629 non-null   float64
#  61  property_logcount                 1629 non-null   float64
#  62  assault_logcount                  1629 non-null   float64
#  63  murder_logcount                   1629 non-null   float64
#  64  rape_logcount                     1629 non-null   float64
#  65  robbery_logcount                  1629 non-null   float64
#  66  burglary_logcount                 1629 non-null   float64
#  67  larceny_logcount                  1629 non-null   float64
#  68  mvt_logcount                      1629 non-null   float64
# dtypes: Float64(1), Int64(2), bool(1), float64(64), str(1)
# memory usage: 903.8 KB
